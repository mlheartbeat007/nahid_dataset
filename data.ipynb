# %%
import pandas as pd ## for creating dataframe
import numpy as np  ## array manupulation

# %%
df=pd.read_csv('data_re.csv') ## read  thedata and create a dataframe

# %%
###ok before go into the machine learning algorithm 
### clean the data

# %%
df.head()  ## peak of the data from the head side
# Out:
#                Date                           Spot  Types of road  Injured  \
# 0       May 01,2018              Hatirjheel, Dhaka              1        0
# 1      June 28,2017  Kalapani,Guimara, Khagrachari              2       10
# 2  February 23,2018               Mymensingh road               2       25
# 3   February 7,2018         Sunamganj pagla bazar               2        0
# 4  December 18,2018                 Gazipur sarak               3        2
#
#    Death                                                How  Insane  Addicted  \
# 0      2  Motorcycle skidded off the road after hitting ...       1         1
# 1      3   After skidded off the road the bus hit the tree.       1         0
# 2      4                    bus felt into Roadside ditch          1         0
# 3      4                    bus and private car collision         0         0
# 4      1                              bus thrush rickshaw         1         0
#
# ...

# %%
df.tail()  ### data from tail side
# Out:
#                   Date                  Spot  Types of road  Injured  Death  \
# 35    December 17,2018    Naval academy road              1        0      0
# 36     january 14,2018        Dhaka Ctg road              4        0      0
# 37  january 19 12,2018    Patiya, Chittagong              1        0      0
# 38     january 27,2018   Chokoria,Coxs Bazar              3        0      0
# 39    December 15,2018  Agrabad  Access road              1        0      0
#
#      How  Insane  Addicted  Unathorized  Less experience  ...  bad weather  \
# 35  no         1         1            0              0.0  ...            0
# 36  no         1         0            0              0.0  ...            0
# 37  no         1         1            0              0.0  ...            0
# 38  no         1         0            0              0.0  ...            0
# 39  no         1         0            0              0.0  ...            0
#
# ...

# %%
## first drop the how column cant deal with it and vehical column
## when we drop a column in pandas it will return a new data frame
df = df.drop('How',1)
df = df.drop('Date',1)
df = df.drop('Spot',1)

# %%
## lets see it again
df.head()
# Out:
#    Types of road  Injured  Death  Insane  Addicted  Unathorized  \
# 0              1        0      2       1         1            0
# 1              2       10      3       1         0            0
# 2              2       25      4       1         0            0
# 3              2        0      4       0         0            1
# 4              3        2      1       1         0            0
#
#    Less experience  overall  Road bad condition  Unconcerpedestrian  \
# 0              0.0     0.50                   0                   0
# 1              0.0     0.25                   0                   1
# 2              1.0     0.50                   1                   1
# 3              0.0     0.25                   1                   0
# 4              0.0     0.25                   1                   0
#
#    bad weather  overall.1  Unfitness  no liscence  Aged  overall.2  \
# 0            0   0.000000          0            0     1   0.333333
# ...

# %%
list(df.columns.values)
# Out:
# ['Types of road',
#  'Injured',
#  'Death',
#  'Insane',
#  'Addicted',
#  'Unathorized',
#  'Less experience',
#  'overall',
#  'Road bad condition',
#  'Unconcerpedestrian',
#  'bad weather',
#  'overall.1',
#  'Unfitness',
#  'no liscence',
#  'Aged',
#  'overall.2',
#  'Unnamed: 19',
#  'Average of total fault',
#  'Accident',
#  'Vehicle']

# %%
### unnamed 14 column has mixed thing removing it
#df=df.drop('Unnamed: 14',1)

# %%
##lets see it now
df.head()
# Out:
#    Types of road  Injured  Death  Insane  Addicted  Unathorized  \
# 0              1        0      2       1         1            0
# 1              2       10      3       1         0            0
# 2              2       25      4       1         0            0
# 3              2        0      4       0         0            1
# 4              3        2      1       1         0            0
#
#    Less experience  overall  Road bad condition  Unconcerpedestrian  \
# 0              0.0     0.50                   0                   0
# 1              0.0     0.25                   0                   1
# 2              1.0     0.50                   1                   1
# 3              0.0     0.25                   1                   0
# 4              0.0     0.25                   1                   0
#
#    bad weather  overall.1  Unfitness  no liscence  Aged  overall.2  \
# 0            0   0.000000          0            0     1   0.333333
# ...

# %%
## creating a function that can perform relation between the survive and dead people with 
## other catagory

## create a bar chart
def barchart(feature):
    survived=df[df['Accident']==1][feature].value_counts()
    dead=df[df['Accident']==0][feature].value_counts()
    #survived1=survived[1]
    #dead1=dead[0]
    df1 = pd.DataFrame([survived,dead])
    df1.index=['survived','dead']
    df1.plot(kind='bar',stacked=True,figsize=(10,5))

# %%
## barchart based on the survived based on different parameter

# %%
barchart('Addicted')   ## how many survived people are addiected and how many dead are addicted

# %%
barchart('Insane') # same like this

# %%
barchart('Unathorized')

# %%
barchart('Road bad condition')

# %%
barchart('no liscence')  ##  survived and dead with lisense and no lisense

# %%
barchart('overall')   ## over all column plotting

# %%
df.isnull().sum()   ## no null digit
df=df.fillna(0)

# %%
df.isnull().sum()
# Out:
# Types of road             0
# Injured                   0
# Death                     0
# Insane                    0
# Addicted                  0
# Unathorized               0
# Less experience           0
# overall                   0
# Road bad condition        0
# Unconcerpedestrian        0
# bad weather               0
# overall.1                 0
# Unfitness                 0
# no liscence               0
# Aged                      0
# overall.2                 0
# Unnamed: 19               0
# Average of total fault    0
# Accident                  0
# Vehicle                   0
# dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC,LinearSVC
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier


## importing all the algorithm

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
x=np.array(df.drop('Accident',1))  ## training featurre

# %%
y=np.array(df['Accident'])        ## traget values

# %%
## slipping the training value
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
MachineLearningAlgo=[]
X=['LinearSVC','DecisionTreeClassifier','KNeighborsClassifier','SVC','GradientBoostingClassifier','RandomForestClassifier']
Z=[LinearSVC(),DecisionTreeClassifier(),KNeighborsClassifier(),SVC(),GradientBoostingClassifier(),RandomForestClassifier()]

# %%
for model in Z:
    model.fit(X_train,y_train)      ## training the model this could take a little time
    accuracy=model.score(X_test,y_test)    ## comparing result with the test data set
    MachineLearningAlgo.append(accuracy)   ## saving the accuracy
# Out:
# /home/vagrant/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/vagrant/.local/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
MachineLearningAlgo
# Out:
# [0.9166666666666666, 1.0, 0.6666666666666666, 0.75, 1.0, 1.0]

# %%
d={'Accuracy':MachineLearningAlgo,'Algorithm':X}
df1=pd.DataFrame(d)

# %%
df1
# Out:
#    Accuracy                   Algorithm
# 0  0.916667                   LinearSVC
# 1  1.000000      DecisionTreeClassifier
# 2  0.666667        KNeighborsClassifier
# 3  0.750000                         SVC
# 4  1.000000  GradientBoostingClassifier
# 5  1.000000      RandomForestClassifier

# %% [markdown]
# ### this is only happen when we get small data set Linear svc done preety well but we get 100% accuracy its only happen in small data set this is from different classification algorithm not from tensor flow so we can compare the result

# %% [markdown]
# ## using tensorflow and keras for deep nural network

# %%
import tensorflow as tf

# %%
## using sequential deep  nural network
model = tf.keras.models.Sequential()

# %%
## adding 5 hidden layer

model.add(tf.keras.layers.Flatten()) #first layer have to be flatten
model.add(tf.keras.layers.Dense(128,activation = tf.nn.relu)) ## then we added a dense layer
model.add(tf.keras.layers.Dense(128,activation = tf.nn.relu)) 
model.add(tf.keras.layers.Dense(128,activation = tf.nn.relu))
model.add(tf.keras.layers.Dense(2,activation = tf.nn.softmax))

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ### we use 1 flatten layer and 5 dense layer that means 6 hidden layer and we use 300 iteration for training the DNN model in tensorflow

# %%
model.fit(X_train,y_train,epochs=300)
# Out:
# Epoch 1/300
# 28/28 [==============================] - 4s 137ms/step - loss: 0.9286 - acc: 0.3571
# Epoch 2/300
# 28/28 [==============================] - 0s 534us/step - loss: 0.6626 - acc: 0.5714
# Epoch 3/300
# 28/28 [==============================] - 0s 466us/step - loss: 0.5453 - acc: 0.6786
# Epoch 4/300
# 28/28 [==============================] - 0s 863us/step - loss: 0.4922 - acc: 0.6429
# Epoch 5/300
# 28/28 [==============================] - 0s 604us/step - loss: 0.4636 - acc: 0.6429
# Epoch 6/300
# 28/28 [==============================] - 0s 735us/step - loss: 0.4425 - acc: 0.6429
# Epoch 7/300
# 28/28 [==============================] - 0s 872us/step - loss: 0.4211 - acc: 0.6429
# Epoch 8/300
# 28/28 [==============================] - 0s 675us/step - loss: 0.3972 - acc: 0.6429
# Epoch 9/300
# 28/28 [==============================] - 0s 768us/step - loss: 0.3720 - acc: 0.7143
# Epoch 10/300
# ...

# %%
val_loss,val_accuracy = model.evaluate(X_test,y_test)
# Out:
# 12/12 [==============================] - 0s 22ms/step

# %%
print (val_accuracy)  ## this accuracy is the total avg accuracy by the time we iterate the 300 time we can 
                        ## get 1
# Out:
# 0.75

# %% [markdown]
# Accoring to the tensorflow deep nural network work well if there is a huge ammount of data so this accuracy with a very smaller dataset is preety good

# %%
# Pass the row elements as key value pairs to append() function 
df2 = df1.append({'Accuracy' : val_accuracy , 'Algorithm' : 'Deep nural network'} , ignore_index=True)

# %% [markdown]
# # <center> Final result comparison </center>

# %%
df2
# Out:
#    Accuracy                   Algorithm
# 0  0.916667                   LinearSVC
# 1  1.000000      DecisionTreeClassifier
# 2  0.666667        KNeighborsClassifier
# 3  0.750000                         SVC
# 4  1.000000  GradientBoostingClassifier
# 5  1.000000      RandomForestClassifier
# 6  0.750000          Deep nural network
